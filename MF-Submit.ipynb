# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Dot, Add, Flatten
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import SGD, Adam

from sklearn.metrics import mean_squared_error

# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - #

# load in the data
df = pd.read_csv('ratings-books.csv')

N = df.user_id.max() + 1 # number of users
M = df.book_id.max() + 1 # number of books
print(f"Number of Users: {N-1}, Number of Books: {M-1}")

print("\nSample of the 'Books-Ratings DataFrame'\n")
print(df.sample(10))

# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - #

# Load the 'Books and Book-Titles' 
df_books_and_titles = pd.read_csv('books.csv')
df_books_and_titles = df_books_and_titles[['book_id','title']]
print("\n\nSample of the 'Books and Book-Titles' dataframe\n")
print(df_books_and_titles.sample(5))

# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - #

# split into train and test
df = shuffle(df)
cutoff = int(0.8*len(df))
df_train = df.iloc[:cutoff]
df_test = df.iloc[cutoff:]
print(f"\nTrain set uses rows 1 thru {cutoff-1}, test set uses rows {cutoff} to {len(df)}")

# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - #

# initialize variables
K = 10 # latent dimensionality
mu = df_train.rating.mean()
epochs = 2
reg = 0. # regularization penalty

# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - #

# keras model
u = Input(shape=(1,),name='user')
m = Input(shape=(1,),name='book')
u_embedding = Embedding(N, K, embeddings_regularizer=l2(reg),name='user_embedding')(u) # (N, 1, K)
m_embedding = Embedding(M, K, embeddings_regularizer=l2(reg),name='book_embedding')(m) # (N, 1, K)

# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - #

u_bias = Embedding(N, 1, embeddings_regularizer=l2(reg))(u) # (N, 1, 1)
m_bias = Embedding(M, 1, embeddings_regularizer=l2(reg))(m) # (N, 1, 1)
x = Dot(axes=2)([u_embedding, m_embedding]) # (N, 1, 1)

# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - #

x = Add()([x, u_bias, m_bias])
x = Flatten()(x) # (N, 1)

# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - #

model = Model(inputs=[u, m], outputs=x)
model.compile(
  loss='mse',
  # optimizer='adam',
  # optimizer=Adam(lr=0.01),
  optimizer=SGD(lr=0.08, momentum=0.9),
  metrics=['mse'],
)

# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - #

r = model.fit(
  x=[df_train.user_id.values, df_train.book_id.values],
  y=df_train.rating.values, 
  epochs=epochs,
  batch_size=128,
  validation_data=(
    [df_test.user_id.values, df_test.book_id.values],
    df_test.rating.values 
  )
)

# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - #

y_pred = model.predict([df_test.user_id.values, df_test.book_id.values]).ravel() 
y_true = df_test.rating.values

#  Compute RMSE
rmse = np.sqrt(mean_squared_error(y_pred=y_pred, y_true=y_true))
print('\n\nTesting Result With DL Matrix-Factorization: {:.4f} RMSE'.format(rmse))

# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - #

di_book_title = {}
for i in range(len(df_books_and_titles)):
    bk_id = df_books_and_titles.loc[i,'book_id']
    title = df_books_and_titles.loc[i,'title']
    di_book_title[bk_id] = title

lst_titles = []
for i in df_test.book_id.values:
    if i > 0:
        tit = di_book_title[i]
        lst_titles.append(tit)
    else:
        lst_titles.append("N/A")

results_df = pd.DataFrame({
    'User ID': df_test.user_id.values,
    'Book ID': df_test.book_id.values,
    'Book Name' : lst_titles,
    'Predicted Rating': np.round(y_pred, 1),
    'Actual Rating': y_true
})

print("\n\n Sample Predictions for Book-Ratings:\n\n")
print(results_df.sample(5))


# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - #

def get_user_id():
    x = int(input(f"Enter a user-id from 1 to {N-1}  (0 to 'quit'): "))
    if x < 1 or x > (N-1):
        return int(0)
    else:
        return int(x)

# now sort them
def Sort_Tuple(tup): 
  
    # reverse = None (Sorts in Ascending order) 
    # key is set to sort using second element of 
    # sublist lambda has been used 
    tup.sort(key = lambda x: x[1],reverse = True) 
    return tup 

def print_books_with_this_rating(id,top_rating):

    lst_userid = np.array([id for i in range(1,M)]).reshape(-1,)
    lst_book_id = np.array([i for i in range(1,M)]).reshape(-1,)    
    
    pred = model.predict([lst_userid,lst_book_id]).ravel() 
    lst_bk_rating = [(lst_book_id[i],pred[i]) for i in range(len(lst_book_id))]
    sorted_lst_bk_rating = Sort_Tuple(lst_bk_rating)
    
    top_index = 0

    for i in range(len(sorted_lst_bk_rating)):
        bk_id,rating = sorted_lst_bk_rating[i]
        if rating <= top_rating:  # first index that is <= top_index
            top_index = i
            break;    
            
    # print out the top 10 books for this user
    print("\n-----------------------------------------------------------------------------\n")
    if top_rating >= 4.00:  #4.00 to 5.00
        print("Books User ",id," will LOVE\n")
    elif top_rating >= 3.00:  #3.00 to 3.99
        print("Books User ",id," will LIKE\n")
    elif top_rating > 2.00:  #2.00 to 2.99
        print("Books User ",id," will consider 'SO-SO'\n")
    elif top_rating > 1.00:  #1.00 to 1.99
        print("Books User ",id," will DISLIKE\n")
    else:
        print("Books User ",id," will HATE\n")

    num_books_to_display = 10
    for i in range(num_books_to_display):
        if (top_index + i) < len(sorted_lst_bk_rating):
            bk_id,rating = sorted_lst_bk_rating[top_index + i]
            bk_title = lst_titles[bk_id]
            if (rating <= top_rating) and ((top_rating - 1.0) <= rating):
                print(f'{bk_title[:65].ljust(70)}  {rating:3.2f}')

# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - #

the_user_id = 5000
while the_user_id != 0:
    the_user_id = get_user_id()
    if the_user_id == 0:
        break
    print_books_with_this_rating(the_user_id,4.99)
    print_books_with_this_rating(the_user_id,3.99)
    print_books_with_this_rating(the_user_id,2.99)
    print_books_with_this_rating(the_user_id,1.99)
    print_books_with_this_rating(the_user_id,0.99)
    print("\n-----------------------------------------------------------------------------\n")

# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - #
# Out:
# Number of Users: 53424, Number of Books: 10000
#
# Sample of the 'Books-Ratings DataFrame'
#
#          user_id  book_id  rating
# 3470350    40841     3462       5
# 5162095    51698     6520       4
# 624641     10820     7025       4
# 4621963    49446        7       5
# 86959       2647     2376       4
# 741322      6609      120       3
# 2100901    28443       84       4
# 2503551    32330     7825       4
# 1192859    17210      507       5
# 5530584    27379     1216       5
#
#
# Sample of the 'Books and Book-Titles' dataframe
#
#       book_id                                              title
# 1826     1827  The Hostile Hospital (A Series of Unfortunate ...
# 850       851            Flowers in the Attic (Dollanganger, #1)
# 3686     3687     Lord of Misrule (The Morganville Vampires, #5)
# 3214     3215                          Acheron (Dark-Hunter #14)
# 6955     6956  Leven Thumps and the Gateway to Foo (Leven Thu...
#
# Train set uses rows 1 thru 4781182, test set uses rows 4781183 to 5976479
# Epoch 1/2
# C:\Users\GlennDean\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\framework\indexed_slices.py:432: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# 37353/37353 [==============================] - 119s 3ms/step - loss: 1.8659 - mse: 1.8659 - val_loss: 0.8220 - val_mse: 0.8220
# Epoch 2/2
# 37353/37353 [==============================] - 121s 3ms/step - loss: 0.7566 - mse: 0.7566 - val_loss: 0.7433 - val_mse: 0.7433
#
#
# Testing Result With DL Matrix-Factorization: 0.8622 RMSE
#
#
#  Sample Predictions for Book-Ratings:
#
#
#          User ID  Book ID                                Book Name  \
# 1175134    24640     8830                       A Cry In The Night
# 1042563     7299      755          Mort (Death, #1; Discworld, #4)
# 1170613    51866      861         Walking Disaster (Beautiful, #2)
# 61837      31536      248                A Midsummer Night's Dream
# 335499     21556      569  The Angel Experiment (Maximum Ride, #1)
#
#          Predicted Rating  Actual Rating
# 1175134               3.8              4
# 1042563               4.0              3
# 1170613               3.6              4
# 61837                 4.4              5
# 335499                3.7              5
# Enter a user-id from 1 to 53424  (0 to 'quit'): 24640
#
# -----------------------------------------------------------------------------
#
# Books User  24640  will LOVE
#
# The Pilot's Wife                                                        4.99
# Anne of Green Gables (Anne of Green Gables, #1)                         4.99
# Twilight: The Graphic Novel, Vol. 1 (Twilight: The Graphic Novel,       4.99
# The Bell Jar                                                            4.99
# Baby Proof                                                              4.99
# Forest Mage (Soldier Son, #2)                                           4.99
# The Diary of a Young Girl                                               4.98
# The Thirteenth Tale                                                     4.98
# Where Good Ideas Come From: The Natural History of Innovation           4.98
# Look Again                                                              4.98
#
# -----------------------------------------------------------------------------
#
# Books User  24640  will LIKE
#
# Killing Kennedy: The End of Camelot                                     3.99
# The Scarlet Letter                                                      3.99
# King Henry IV, Part 1 (Wars of the Roses, #2)                           3.99
# Unbelievable (Pretty Little Liars, #4)                                  3.99
# Where the Sidewalk Ends                                                 3.99
# Beezus and Ramona (Ramona, #1)                                          3.99
# Big Stone Gap (Big Stone Gap, #1)                                       3.99
# Heart-Shaped Box                                                        3.99
# The Two Towers (The Lord of the Rings, #2)                              3.99
# Stuart Little                                                           3.99
#
# -----------------------------------------------------------------------------
#
# Books User  24640  will consider 'SO-SO'
#
# The Man Who Listens to Horses                                           2.93
# Moll Flanders                                                           2.89
# The Twits                                                               2.86
# Night (The Night Trilogy #1)                                            2.72
# Insurgent (Divergent, #2)                                               2.68
# The Summer I Turned Pretty (Summer, #1)                                 2.66
# Shaman's Crossing (Soldier Son, #1)                                     2.62
# Calamity (The Reckoners, #3)                                            2.55
# A Perfect Blood (The Hollows, #10)                                      2.51
# Wuthering Heights                                                       2.30
#
# -----------------------------------------------------------------------------
#
# Books User  24640  will DISLIKE
#
# Revival                                                                 1.55
# The Queen of the Tearling (The Queen of the Tearling, #1)               1.49
#
# -----------------------------------------------------------------------------
#
# Books User  24640  will HATE
#
#
# -----------------------------------------------------------------------------
#
# Enter a user-id from 1 to 53424  (0 to 'quit'): 1
#
# -----------------------------------------------------------------------------
#
# Books User  1  will LOVE
#
# Mr. Murder                                                              4.53
# Girl with a Pearl Earring                                               4.42
# Winter (The Lunar Chronicles, #4)                                       4.39
# A Reliable Wife                                                         4.38
# Life of Pi                                                              4.38
# Water for Elephants                                                     4.37
# Edge of Eternity (The Century Trilogy, #3)                              4.35
# Angels & Demons  (Robert Langdon, #1)                                   4.33
# The Count of Monte Cristo                                               4.33
# Dead Until Dark (Sookie Stackhouse, #1)                                 4.33
#
# -----------------------------------------------------------------------------
#
# Books User  1  will LIKE
#
# A Midsummer Night's Dream                                               3.99
# The Lion, the Witch, and the Wardrobe (Chronicles of Narnia, #1)        3.99
# Blackwood Farm (The Vampire Chronicles, #9)                             3.99
# Knife of Dreams (Wheel of Time, #11)                                    3.99
# The 80/20 Principle: The Secret to Achieving More with Less             3.99
# Into Thin Air: A Personal Account of the Mount Everest Disaster         3.99
# How the Grinch Stole Christmas!                                         3.99
# Cop Town                                                                3.99
# Messenger (The Giver, #3)                                               3.99
# Beowulf                                                                 3.99
#
# -----------------------------------------------------------------------------
#
# Books User  1  will consider 'SO-SO'
#
# The Secret Diary of Adrian Mole, Aged 13 3/4  (Adrian Mole, #1)         2.99
# The Legend of Sleepy Hollow and Other Stories                           2.99
# The Emperor's Code (The 39 Clues, #8)                                   2.99
# The Secret Life of Bees                                                 2.99
# The Body                                                                2.99
# A Thousand Splendid Suns                                                2.99
# Paper Towns                                                             2.99
# A Spell for Chameleon (Xanth #1)                                        2.99
# On Writing: A Memoir of the Craft                                       2.99
# The Fountainhead                                                        2.99
#
# -----------------------------------------------------------------------------
#
# Books User  1  will DISLIKE
#
# The Twits                                                               1.98
# Night (The Night Trilogy #1)                                            1.84
# Insurgent (Divergent, #2)                                               1.80
# The Summer I Turned Pretty (Summer, #1)                                 1.79
# Shaman's Crossing (Soldier Son, #1)                                     1.74
# Calamity (The Reckoners, #3)                                            1.67
# A Perfect Blood (The Hollows, #10)                                      1.63
# Wuthering Heights                                                       1.42
#
# -----------------------------------------------------------------------------
#
# Books User  1  will HATE
#
# Revival                                                                 0.68
# The Queen of the Tearling (The Queen of the Tearling, #1)               0.61
#
# -----------------------------------------------------------------------------
